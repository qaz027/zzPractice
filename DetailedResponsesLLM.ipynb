# %% [markdown]
# # Lesson: Expanding Content: Encouraging Detailed Responses from LLMs
# Introduction
#
# Today, we explore the strategy of eliciting longer, more detailed responses from Large Language Models (LLMs). In contrast to seeking concise outputs, there are scenarios where depth, detail, and expansiveness enrich the interaction, such as storytelling, in-depth analysis, or comprehensive explanations. Our focus is on mastering the art of crafting prompts that encourage LLMs to "open up" and provide us with the wealth of information they're capable of generating.
# The Challenge of Eliciting Detailed Responses
#
# While LLMs are almost never succinct unless specifically asked to be, they are also almost never very thorough unless again they are specifically asked to be.
#
# Here is a simplistic example prompt:
#
# Markdown
#
# __ASK__
#
# What is the story of Romeo and Juliet?
#
# This would give you a response that's roughly 300-450 words long (depending on the LLM being used). Considering that the actual story is close to 25,000 words, that's not much detail. What if we wanted the LLM to go deeper?
# Simple Approach: Requesting Detailed Responses Directly
#
# A direct method to obtain more detailed information is to explicitly ask for it within the prompt's constraints. This strategy relies on clearly communicating your expectations for a detailed or lengthy response.
#
# Markdown
#
# __ASK__
#
# What is the story of Romeo and Juliet?
#
#
# __CONSTRAINTS__
#
# - Provide a detailed summary, including major themes, character development, and pivotal moments.
#
# This will start to push the response close to 600 words, which is a 50% improvement on what we had so far, not bad.
# Complex Approach: Iterative Enhancement
#
# For even greater depth and structure, we can employ an iterative enhancement strategy. This involves first asking for an outline or skeleton of the desired content, then requesting the LLM to elaborate on each part of the outline, and finally asking for further enhancements or details for each section.
#
# Step 1: Request an Outline
#
# Markdown
#
# __ASK__
#
# Provide an outline for a detailed analysis of "Romeo and Juliet."
#
#
# __CONSTRAINTS__
#
# - Focus on structure, key points, and themes.
#
# Step 2: Request Elaboration on Each Part
#
# Markdown
#
# __ASK__
#
# Based on the outline provided in the CONTEXT, elaborate on each point with detailed information and analysis.
#
#
# __CONSTRAINTS__
#
# - Ensure each section is comprehensive and well-explained.
#
#
# __CONTEXT__
#
# > OUTPUT_FROM_PREVIOUS_PROMPT
#
# This iterative approach not only encourages an initially structured and detailed response but also builds upon it to achieve an even greater level of depth and elaboration. You can of course add a Step 3 here and repeat the same approach again but you'll start running out of context windows at that point, especially with this specific topic.
# Time to Practice
#
# Armed with these strategies, you're now equipped to craft prompts that encourage LLMs to generate longer, more detailed responses. Experimenting with both the simple and complex approaches will help you understand the nuances of prompt design and how to best utilize the capabilities of LLMs for detailed outputs.

# %% [markdown]
# # Exercises
#
# Create a simple prompt that produces a syllabus for a Sales Strategy course. Make sure your prompt doesn't return anything but the syllabus.
#
# __ASK__
# create a syllabus for a Sales Strategy course

# %% [markdown]
# **Sales Strategy Course Syllabus**
#
# **Course Overview:**
# This course is designed to equip students with the foundational skills and knowledge required to develop and implement effective sales strategies. Through a combination of lectures, case studies, and practical exercises, students will explore key concepts in sales management, customer relationship management, market analysis, and strategic planning.
#
# **Course Objectives:**
# - Understand the fundamentals of sales strategy and its role in business success.
# - Analyze customer needs and market trends to develop targeted sales strategies.
# - Learn techniques for building and managing high-performing sales teams.
# - Explore tools and technologies that support modern sales strategies.
# - Develop strategic planning skills to align sales objectives with business goals.
#
# **Course Outline:**
#
# **Week 1: Introduction to Sales Strategy**
# - Definition and importance of sales strategy
# - Evolution of sales in a digital world
# - The role of sales in the broader business strategy
#
# **Week 2: Understanding the Customer**
# - Identifying customer needs and preferences
# - Customer segmentation and target market selection
# - Building and managing customer relationships
#
# **Week 3: Market Analysis and Competitive Positioning**
# - Conducting market research and analysis
# - Understanding competitive landscape
# - Positioning products and services effectively
#
# **Week 4: Sales Planning and Forecasting**
# - Setting strategic sales goals and objectives
# - Sales forecasting methods and tools
# - Aligning sales plans with business strategy
#
# **Week 5: Building a High-Performing Sales Team**
# - Recruiting and hiring sales talent
# - Training and development for sales effectiveness
# - Motivation and compensation strategies
#
# **Week 6: Sales Channels and Distribution Strategies**
# - Direct vs. indirect sales channels
# - Choosing the right distribution strategy
# - Managing channel relationships
#
# **Week 7: Leveraging Technology in Sales**
# - CRM systems and sales automation tools
# - Data analytics and insights in sales
# - Emerging technologies: AI, chatbots, and more
#
# **Week 8: Sales Process and Pipeline Management**
# - Designing effective sales processes
# - Managing and optimizing the sales pipeline
# - Techniques for closing sales deals
#
# **Week 9: International Sales Strategy**
# - Challenges of global sales expansion
# - Adapting sales strategies for international markets
# - Legal and cultural considerations
#
# **Week 10: Ethics and Social Responsibility in Sales**
# - Ethical considerations in sales practices
# - Building trust and credibility with customers
# - Corporate social responsibility and its impact on sales
#
# **Week 11: Financial Acumen for Sales Professionals**
# - Understanding key financial metrics
# - Pricing strategies and profitability
# - Budgeting and resource allocation in sales
#
# **Week 12: Sales Strategy Case Studies and Project Work**
# - Analysis of successful sales strategies from leading companies
# - Group project presentations: Developing a comprehensive sales strategy
#
# **Assessment Methods:**
# - Participation and class discussions
# - Weekly quizzes and assignments
# - Mid-term exam
# - Group project and presentation
# - Final exam
#
# **Required Texts and Materials:**
# - Course textbook: "Sales Strategy: A Guide to Market Leadership"
# - Access to case studies and supplementary reading materials
# - Software tools for sales analytics and CRM (provided by the institution)
#
# **Additional Information:**
# - Office hours: [Insert times and location]
# - Contact information: [Insert instructor email/phone]
# - Course website/online platform: [Insert URL]
#
# This syllabus provides a framework for a comprehensive study of sales strategy, equipping students to effectively contribute to and lead sales efforts in various business environments.

# %% [markdown]
# A syllabus typically provides an overview of a course and outlines what students can expect throughout its duration. Here are common elements included in a syllabus:
#
# 1. **Course Information**:
#    - Course title and code
#    - Semester or term offered
#    - Meeting times and location(s)
#
# 2. **Instructor Information**:
#    - Name of the instructor(s)
#    - Contact information (email, phone number)
#    - Office hours and location
#
# 3. **Course Description**:
#    - Brief summary of the course content and objectives
#    - Prerequisites or co-requisites, if any
#
# 4. **Learning Outcomes**:
#    - Specific skills or knowledge students are expected to acquire by the end of the course
#
# 5. **Required Materials**:
#    - Textbooks, articles, or online resources
#    - Supplies or equipment needed
#
# 6. **Course Outline/Schedule**:
#    - Weekly or session-based breakdown of topics and activities
#    - Important dates (exams, assignments due, holidays)
#
# 7. **Assessment and Grading**:
#    - Methods of evaluation (exams, quizzes, papers, projects, etc.)
#    - Grading scale and weight of each element towards final grade
#
# 8. **Policies**:
#    - Attendance and participation expectations
#    - Late work and makeup exam policies
#    - Academic integrity or plagiarism policy
#
# 9. **Support and Resources**:
#    - Information on tutoring, writing centers, or disability services
#    - Links to online platforms or course management systems used
#
# 10. **Additional Information**:
#     - Optional: class etiquette, group work guidelines, extra credit opportunities
#
# Crafting a comprehensive syllabus helps set clear expectations and provides essential guidance for students throughout the course.

# %% [markdown]
# __ASK__
# create a syllabus for a Sales Strategy course
#
# __CONSTRAINTS__
# - return only elements of the syllabus
# - no intro
# - no outtro
#
# Course Title: Sales Strategy
#
# Course Duration: 10 Weeks
#
# 1. **Week 1: Introduction to Sales Strategy**
#    - Definition and Importance of Sales Strategy
#    - Components of an Effective Sales Strategy
#    - Aligning Sales Strategy with Business Goals
#
# 2. **Week 2: Market Research and Customer Analysis**
#    - Identifying Target Markets
#    - Customer Segmentation and Profiling
#    - Understanding Buyer Behavior
#
# 3. **Week 3: Competitive Analysis**
#    - Analyzing Competitors
#    - SWOT Analysis for Competitors
#    - Developing a Competitive Positioning
#
# 4. **Week 4: Setting Sales Goals and Quotas**
#    - Establishing SMART Sales Objectives
#    - Sales Forecasting Techniques
#    - Allocating Sales Quotas
#
# 5. **Week 5: Sales Process Design and Optimization**
#    - Designing the Sales Funnel
#    - Streamlining Sales Processes
#    - Tools and Technologies for Sales Process Management
#
# 6. **Week 6: Building a Sales Team**
#    - Recruitment and Selection Strategies
#    - Training and Development of Sales Teams
#    - Motivating and Incentivizing Sales Personnel
#
# 7. **Week 7: Sales Tactics and Techniques**
#    - Effective Prospecting Methods
#    - Consultative Selling Techniques
#    - Closing Sales and Overcoming Objections
#
# 8. **Week 8: Relationship Management and Customer Retention**
#    - Building Long-term Customer Relationships
#    - Implementing CRM Systems
#    - Strategies for Customer Retention and Loyalty
#
# 9. **Week 9: Measuring and Analyzing Sales Performance**
#    - Key Sales Metrics and KPIs
#    - Analytical Tools for Sales Performance
#    - Continuous Improvement through Feedback and Analysis
#
# 10. **Week 10: Sales Strategy Implementation and Review**
#     - Developing a Sales Action Plan
#     - Implementing and Adjusting Sales Strategies
#     - Case Studies and Best Practices in Sales Strategy
#
# Assessments:
# - Weekly Assignments
# - Case Study Analysis
# - Final Project: Develop a Comprehensive Sales Strategy Plan
#
# Readings & Resources:
# - Selected articles and case studies from industry publications
# - Recommended books and online resources
#
# Teaching Methodology:
# - Lectures and Discussions
# - Group Projects and Role-plays
# - Guest Lectures from Industry Experts

# %% [markdown]
# Let's take things one step further, enhance this prompt to make the syllabus contain at least three layers of bullets for added detail. Notice how this simple technique allows you to get a much more detailed response.
#
# __ASK__
# Give me a syllabus for a course on sales strategy.
#
# __CONSTRAINTS__
# - Do not start with an intro
# - Just give me the syllabus as a bulleted list.
# - Each element of the syllabus should include at least 3 layers of bullets of additional detail
#
# ---
#
# - Understanding the Sales Ecosystem
#   - Market Analysis
#     - Identifying Target Markets
#       - Demographic Research
#       - Behavioral Segmentation
#       - Geographic and Psychographic Data
#     - Competitor Analysis
#       - SWOT Analysis
#       - Positioning Strategies
#       - Competitive Differentiation
#     - Industry Trends
#       - Technological Advancements
#       - Economic Factors
#       - Regulatory Changes
#
# - Sales Strategy Development
#   - Creating a Value Proposition
#     - Unique Selling Points (USPs)
#       - Product Advantages
#       - Service Differentiation
#       - Customer Experience
#     - Aligning with Customer Needs
#       - Problem Identification
#       - Solution Mapping
#       - Value Communication
#   - Setting Sales Objectives
#     - Short-term Goals
#       - Monthly Revenue Targets
#       - Lead Conversion Rates
#       - Customer Retention Goals
#     - Long-term Vision
#       - Market Share Growth
#       - Brand Positioning
#       - Product Line Expansion
#
# - Building and Managing a Sales Team
#   - Recruitment and Selection
#     - Identifying Key Competencies
#       - Sales Experience
#       - Communication Skills
#       - Cultural Fit
#     - Interview Techniques
#       - Behavioral Interviewing
#       - Role-playing Scenarios
#       - Reference Checks
#   - Training and Development
#     - Onboarding Programs
#       - Product Knowledge
#       - Sales Process Training
#       - CRM Systems Usage
#     - Continuous Learning
#       - Workshops and Seminars
#       - E-learning Platforms
#       - Mentorship and Coaching
#
# - Sales Process and Techniques
#   - Lead Generation
#     - Inbound Strategies
#       - Content Marketing
#       - Social Media Engagement
#       - SEO Best Practices
#     - Outbound Techniques
#       - Cold Calling
#       - Email Campaigns
#       - Networking Events
#   - Negotiation Skills
#     - Understanding Buyer Psychology
#       - Behavioral Cues
#       - Emotional Intelligence
#       - Trust Building
#     - Closing Techniques
#       - Overcoming Objections
#       - Value Justification
#       - Creating Urgency
#
# - Sales Technology and Tools
#   - CRM Systems
#     - Data Management
#       - Contact Database Organization
#       - Sales Funnel Tracking
#       - Customer Interaction Recording
#     - Automation Features
#       - Follow-up Scheduling
#       - Email Templates
#       - Reporting and Analytics
#   - Analytics and Metrics
#     - Key Performance Indicators (KPIs)
#       - Sales Conversion Rates
#       - Pipeline Velocity
#       - Customer Lifetime Value
#     - Data Interpretation
#       - Trend Analysis
#       - Predictive Modeling
#       - Decision-Making Insights
#
# - Customer Relationship Management
#   - Building Customer Loyalty
#     - Engagement Strategies
#       - Personalized Communication
#       - Feedback Mechanisms
#       - Loyalty Programs
#     - Relationship Building
#       - Regular Check-ins
#       - Value-add Initiatives
#       - Surprise and Delight Tactics
#   - Handling Disputes and Complaints
#     - Conflict Resolution Techniques
#       - Active Listening
#       - Empathy Development
#       - Solution Orientation
#     - Recovery Strategies
#       - Apology and Compensation
#       - Issue Resolution Follow-up
#       - Long-term Relationship Repair
#
# - Evaluating and Improving Sales Performance
#   - Performance Reviews
#     - Individual Assessments
#       - Strengths and Weaknesses
#       - Goal Alignment
#       - Growth Opportunities
#   - Team Analysis
#       - Collaboration Effectiveness
#       - Team Dynamics
#       - Motivation Techniques
#   - Sales Strategy Revision
#     - Outcome Analysis
#       - Success Metrics Review
#       - Gap Identification
#       - Adaptation and Iteration
#     - Innovation and Adaptability
#       - New Market Exploration
#       - Technological Integration
#       - Continuous Improvement Initiatives

# %% [markdown]
# Now let's use the iterative enhancement approach we've learned to make our syllabus even better. Start by running this prompt to get an initial output then use that while modifying your prompt to enhance what you have.
#
# Make sure to update the constraints and include the format example for LLM to follow.
#
# __ASK__
# Create a syllabus for a basic course on Sales Strategy.
#
# __CONSTRAINTS__
# - Structure the syllabus in a bulleted list format.
# - Do not start with an intro, just give me the syllabus.
# - Enhance the example with additional detail - at least 3 bullets deep
#
# __EXAMPLE__
# - **Week 1: Introduction to Sales Strategy**
#   - Overview of Sales and Marketing
#   - Understanding the Sales Process
#   - Key Concepts & Terminology
#
# - **Week 2: Market Research and Analysis**
#   - Identifying Target Markets
#   - Conducting Competitor Analysis
#   - Understanding Consumer Behavior
#
# - **Week 3: Developing a Sales Strategy**
#   - Setting Sales Goals and Objectives
#   - Designing a Customer Value Proposition
#   - Identifying Sales Channels
#
# - **Week 4: Sales Planning and Forecasting**
#   - Creating a Sales Plan
#   - Techniques for Sales Forecasting
#   - Measuring and Analyzing Sales Performance
#
# - **Week 5: Building and Managing a Sales Team**
#   - Sales Team Structure and Roles
#   - Recruitment and Training
#   - Motivation and Compensation Strategies
#
# - **Week 6: Customer Relationship Management (CRM)**
#   - Importance of CRM in Sales Strategy
#   - Implementing CRM Systems
#   - Leveraging CRM Data for Sales
#
# - **Week 7: Sales Tactics and Techniques**
#   - Consultative Selling
#   - Negotiation Skills
#   - Overcoming Objections
#
# - **Week 8: Digital Sales Strategies**
#   - Online Sales Platforms
#   - Social Media and Sales
#   - Email and Content Marketing
#
# - **Week 9: Building Long-term Customer Relationships**
#   - Importance of Customer Retention
#   - Strategies for Enhancing Customer Loyalty
#   - Using Feedback to Improve Sales
#
# - **Week 10: Evaluating and Improving Sales Strategies**
#   - Metrics for Evaluation
#   - Adjusting Strategies Based on Performance
#   - Continuous Improvement in Sales
#
# - **Week 11: Case Studies and Practical Applications**
#   - Analyzing Successful Sales Strategies
#   - Group Project: Develop a Sales Strategy Proposal
#   - Peer Feedback and Discussion
#
# - **Week 12: Final Review and Examination**
#   - Recap of Key Concepts and Strategies
#   - Preparation for Final Exam
#   - Future Trends in Sales Strategy
#
# - **Additional Resources:**
#   - Recommended Reading List
#   - Online Sales Tools and Platforms
#   - Industry Guest Speaker Sessions

# %% [markdown]
# - **Week 1: Introduction to Sales Strategy**
#   - Overview of Sales and Marketing
#     - Differences and similarities between sales and marketing
#     - Evolution of sales strategy over time
#   - Understanding the Sales Process
#     - Steps of a typical sales cycle
#     - Significance of each step in the sales funnel
#   - Key Concepts & Terminology
#     - Common sales terms and jargon
#     - Defining roles within a sales team
#
# - **Week 2: Market Research and Analysis**
#   - Identifying Target Markets
#     - Techniques for segmenting markets
#     - Tools for identifying market needs
#   - Conducting Competitor Analysis
#     - Frameworks for analyzing competitors
#     - Identifying competitive advantages
#   - Understanding Consumer Behavior
#     - Psychological factors influencing purchasing decisions
#     - Cultural and social influences on buying habits
#
# - **Week 3: Developing a Sales Strategy**
#   - Setting Sales Goals and Objectives
#     - SMART criteria for goal setting
#     - Aligning goals with company vision
#   - Designing a Customer Value Proposition
#     - Crafting unique selling propositions
#     - Communicating value effectively to customers
#   - Identifying Sales Channels
#     - Exploring direct and indirect sales channels
#     - Evaluating channel effectiveness
#
# - **Week 4: Sales Planning and Forecasting**
#   - Creating a Sales Plan
#     - Components of a sales plan
#     - Aligning sales plans with business strategy
#   - Techniques for Sales Forecasting
#     - Quantitative vs. qualitative forecasting methods
#     - Importance of historical data analysis
#   - Measuring and Analyzing Sales Performance
#     - KPI selection and alignment with objectives
#     - Data analysis tools and techniques
#
# - **Week 5: Building and Managing a Sales Team**
#   - Sales Team Structure and Roles
#     - Defining roles and responsibilities
#     - Structuring teams for optimal performance
#   - Recruitment and Training
#     - Best practices in hiring
#     - Developing sales training programs
#   - Motivation and Compensation Strategies
#     - Structuring incentives and bonuses
#     - Psychological motivators in sales
#
# - **Week 6: Customer Relationship Management (CRM)**
#   - Importance of CRM in Sales Strategy
#     - Entrenchment of CRM in modern sales
#     - CRM’s role in customer loyalty and retention
#   - Implementing CRM Systems
#     - Comparing popular CRM software
#     - Best practices in CRM implementation
#   - Leveraging CRM Data for Sales
#     - Analyzing CRM data for actionable insights
#     - Customizing sales approaches based on data
#
# - **Week 7: Sales Tactics and Techniques**
#   - Consultative Selling
#     - Understanding client needs through consultative sales
#     - Establishing trust and rapport in customer interactions
#   - Negotiation Skills
#     - Strategies for successful negotiations
#     - Common negotiation pitfalls and how to avoid them
#   - Overcoming Objections
#     - Techniques for addressing customer concerns
#     - Building confidence through objection handling
#
# - **Week 8: Digital Sales Strategies**
#   - Online Sales Platforms
#     - Evaluating ecommerce platforms
#     - Online sales strategies for different industries
#   - Social Media and Sales
#     - Leveraging social media for lead generation
#     - Case studies of successful social media campaigns
#   - Email and Content Marketing
#     - Crafting effective email campaigns
#     - Role of content in nurturing leads
#
# - **Week 9: Building Long-term Customer Relationships**
#   - Importance of Customer Retention
#     - Cost comparison of retention vs. acquisition
#     - Customer lifecycle value analysis
#   - Strategies for Enhancing Customer Loyalty
#     - Building customer loyalty programs
#     - Implementing customer feedback loops
#   - Using Feedback to Improve Sales
#     - Techniques for collecting and using feedback
#     - Case studies of feedback-driven improvements
#
# - **Week 10: Evaluating and Improving Sales Strategies**
#   - Metrics for Evaluation
#     - Identifying key performance indicators (KPIs)
#     - Using dashboards for performance tracking
#   - Adjusting Strategies Based on Performance
#     - Frameworks for strategic adjustments
#     - Anticipating market changes and trends
#   - Continuous Improvement in Sales
#     - Implementing sales Kaizen practices
#     - Encouraging a culture of improvement
#
# - **Week 11: Case Studies and Practical Applications**
#   - Analyzing Successful Sales Strategies
#     - Dissecting real-world sales successes
#     - Lessons learned from failed strategies
#   - Group Project: Develop a Sales Strategy Proposal
#     - Collaborating on a comprehensive sales plan
#     - Presenting and defending sales proposals
#   - Peer Feedback and Discussion
#     - Constructive feedback strategies
#     - Discussion on diverse sales perspectives
#
# - **Week 12: Final Review and Examination**
#   - Recap of Key Concepts and Strategies
#     - Summarizing all concepts learned
#     - Preparing study guides for exam
#   - Preparation for Final Exam
#     - Exam format and study tips
#     - Q&A session
#   - Future Trends in Sales Strategy
#     - Understanding the impact of AI on sales
#     - Emerging sales technologies
#
# - **Additional Resources:**
#   - Recommended Reading List
#     - Curated list of books and articles
#     - Subscriptions to relevant industry journals
#   - Online Sales Tools and Platforms
#     - List of free and premium sales tools
#     - Tutorials for effective tool use
#   - Industry Guest Speaker Sessions
#     - Scheduling guest lectures
#     - Field experts sharing real-world experiences
