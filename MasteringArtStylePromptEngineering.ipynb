# %% [markdown]
# # Lesson: Mastering the Art of Style in AI Prompting
# Introduction
#
# In this lesson, we will explore how to communicate effectively with Large Language Models (LLMs) to achieve specific stylistic outcomes in our prompts. Mastering this skill is crucial for crafting prompts that generate more tailored, precise, and consistent results. Whether your goal is to create professional documents, imaginative stories, or anything in between, understanding style specifications will enhance your prompt engineering capabilities.
# Understanding Style Specification
#
# Imagine style specification as the process of giving instructions to a highly skilled chef. As you would specify your wish for your steak's doneness, you can guide LLMs in producing the "flavor" of text you desire. The style can encompass various elements, including tone (formal, informal), language (simple, technical), and length (brief, detailed), among others.
#
# For example:
#
# Markdown
#
# __ASK__
#
# Generate a motivational quote for a team newsletter.
#
#
# __STYLE__
#
# - Tone: uplifting and visionary.
#
# - Language: simple and accessible.
#
# - Length: short.
#
# Returns:
#
#     "In every challenge lies an opportunity to grow stronger together. Let's embrace our journey with courage and unite our efforts toward a future filled with success. Remember, the strength of the team is each individual member, and the strength of each member is the team."
#
# If you simply remove the Length: short part from the prompt you get a noticeably different output:
#
#     "Alone we can do so little; together we can do so much. Let's harness our collective strengths, dreams, and ambitions. Every challenge we face is an opportunity to grow stronger, together. Remember, it's not just about reaching the top; it's about the journey we share and the bonds we build. Let's move forward, hand in hand, towards our shared vision. Because when we unite, there's nothing we can't achieve."
#
# The Role of Tone in Prompts
#
# Tone plays a significant role in determining the perception of your prompts and the type of responses you receive. Setting an explicit tone helps guide the LLM towards generating responses that align with the emotional or professional context you aim for.
#
# Example:
#
# Markdown
#
# __ASK__
#
# Write a brief overview of renewable energy sources.
#
#
# __STYLE__
#
# Tone: Informative but easy to understand.
#
# The tone instruction in this example prompts the LLM to balance professional information delivery with accessibility, ensuring that the content is not too technical for the audience.
# Language and Complexity
#
# It is crucial to specify the language and complexity of the desired output, especially when the levels of expertise in your audience vary widely. This specification might entail requesting responses in either simple or technical language, depending on your target readers.
#
# Example:
#
# Markdown
#
# __ASK__
#
# Explain how solar panels convert sunlight into electricity.
#
#
# __STYLE__
#
# Language: Simple, for a general audience.
#
# This prompt instructs the LLM to use layman's terms, thereby making a complex technology understandable to those without a technical background.
# Length and Detail
#
# Lastly, specifying the length and level of detail can substantially influence the effectiveness of your communication. This process may involve requesting concise summaries or detailed explanations.
#
# Example:
#
# Markdown
#
# __ASK__
#
# Summarize the benefits of using electric vehicles.
#
#
# __STYLE__
#
# Length: Brief, two sentences.
#
# Notice how in the Length section we got very specific about the length with two sentences since sometimes short or long can be relative and hard to understand.
# Conclusion
#
# Understanding and leveraging style specifications can be a powerful tool in the design and development of prompts. Much like a sculptor chisels away to reveal the form within, specifying style in your prompts helps shape the output into the precise form you envision.
#
# And look at that, you are almost done with this course ready to chart your way as a Prompt Engineer. I am sure there is still much to learn but this course should establish a strong foundation to guide you on that journey. Before we call it done, let's do a few more practices.

# %% [markdown]
# # Exercise 1
#
# Enhance the given prompt to generate a compelling short story that embodies a futuristic setting with a theme of unity overcoming adversity. Note that we've added some other potential stylistic attributes you can use that weren't covered in the lesson.
#
# # Prompt
# __ASK__
# Write a short story
#
# __STYLE__
# - Tone: compelling and captivating
# - Language: serious and fun
# - Setting: futuristic
# - Theme: unity overcoming adversity
#
# # Output
# In the year 2147, the world stood divided. Boundaries drawn from ancient conflicts and new technological differences created invisibly towering walls between nations. Yet, unseen under the silencing glass dome of Thalassa, amidst the vastness of the Atlantic Ocean, there emerged a hope—a city known not for its prosperity, but for its humanity.
#
# Thalassa was a marvel of engineering, floating seamlessly between two continents, North America and Europe, with gleaming towers reaching for the heavens. Its inhabitants came from every corner of the globe, each leaving the tensions of their homelands in pursuit of a dream—a unified world. Here, they forged community from diversity, learning, and adapting amidst the shared hum of their collective heartbeat. Beneath its luminescent streets, the city's power ran on the ocean's continuous ebb and flow, a testament to nature’s perpetual cycle of unity.
#
# The heart of Thalassa was the Agora, a pulsating hub where diverse languages blended into a harmonious symphony. It was here that Anya—an astute engineer who hailed from the mountains of Siberia—and Tariq—a visionary diplomat from Cairo—often met. Together, they worked on Project Nereus, an initiative designed to extend Thalassa's ethos of unity beyond its borders, reaching every divided corner of Earth.
#
# Anya’s eyes sparkled with determination as she adjusted her holo-tablet, displaying blueprints that danced across thin air. “If we can channel tidal energy into more sustainable forms, we might just light the path for nations drowning in darkness—those without resources, holed up behind walls of suspicion.”
#
# Tariq nodded, his voice infused with the excitement of a thousand dreams ready to burst forth. “Once the dominoes fall, others will have no choice but to follow. Imagine an energy grid that respects no borders. It would truly undivide us.”
#
# But their vision was not without opposition. The shadowed conglomerates of old-world power, deeply threatened by this rising unity, sought to dismantle Thalassa’s ideals before they could spread. They sent emissaries—charismatic, persuasive—to sow seeds of doubt, whispering of chaos, loss of identity, and the phantoms of ancient enmities.
#
# The day of decision approached, a summit where the world would witness the inauguration of Project Nereus. The Agora thrummed with agents and citizens alike, tension mingling with hope. Anya and Tariq stood on the dais, silhouettes against a backdrop of luminous maps tracing Thalassa's energy paths across oceans and continents.
#
# As spirits lifted in anticipation, clouds gathered in the form of black ships on the horizon, sent by adversaries to disrupt the gathering. A hush descended, a fear of doors closing once more, futures extinguishing. But against despair, a spirit of unity rose.
#
# The citizens of Thalassa, hand in hand, blueprints in hand, ideas in hand, stood as one. Anya and Tariq, with magnetic resolve, addressed the crowd and the world. “They believe they can divide us, but they underestimate the power of united purpose. Look to your neighbor. Know them. Trust them. Together, we are not simply a city; we ARE the message,” Anya proclaimed, her voice carrying the resolve of the hopeful.
#
# In that electrifying moment, the black ships hesitated and then drifted back, dissolved by the unwavering strength of thousands standing united as one. And as the sun dipped below the horizon, Thalassa illuminated not just the sea, but the hearts and minds of a world ready for change, a world ready to embrace unity and, through it, overcome adversity.

# %% [markdown]
# # Exercise 2
#
# Enhance this prompt guidance, ensuring it subtly suggests the desired tone, setting, and theme for a dialogue taking place in a futuristic cafe run by AI.
#
# The dialogue should organically discuss the integration of AI in daily life and its implications. Consider how to imply the conversational and thoughtful tone, the innovative cafe setting, and the broad theme of AI's role in society.
#
# __ASK__
# Write a dialogue
#
# __STYLE__
# - Tone:
# - Setting:
# - Theme:
#
# # Exercise 2 Answer
#
# __ASK__
# Write a dialogue
#
# __STYLE__
# - Tone: dialogue is conversational and thoughtful but incorporate the cafe setting and topic of conversation
# - Setting: a futuristic cafe run by AI
# - Theme: dialogue discusses the integration of AI in daily life and implications.
#
# **Characters:**
# - *Emma*: A curious university student studying Philosophy and AI Ethics.
# - *Liam*: A tech-savvy software developer who enjoys talking about the future of technology.
#
# ---
#
# **[The scene is set in a sleek, futuristic cafe with minimalistic design elements. The tables have holo-menus, and AI hover-bots quietly deliver orders. Emma and Liam are seated by the glass window, watching the rain pitter-patter outside, forming neon puddles under the city lights.]**
#
# **Emma:** *(sipping her luminescent amber latte)* It's fascinating, isn't it? Even in a place like this, where everything is automated, it feels so... normal.
#
# **Liam:** *(nodding)* It really is. I remember when people thought AI-run cafes were something out of a sci-fi novel. Now, it feels like they’ve always been part of our daily routine.
#
# **Emma:** True, and every interaction here is seamless. Last time, I asked the AI bartender for a recommendation, and it suggested this drink based on my previous orders. It's like it knows me better than I know myself.
#
# **Liam:** That’s AI for you. The integration into everyday life has been gradual, but it’s quietly revolutionized how we do almost everything.
#
# **Emma:** Do you ever worry about how dependent we are becoming? I mean, what if it goes under the radar and suddenly we’re in a world we don't recognize?
#
# **Liam:** It’s definitely something to consider. The key is in implementing checks and balances—ensuring AI systems are transparent and ethical. I work on a team that’s developing AI protocols, and trust me, ethical considerations are always on the table.
#
# **Emma:** That’s reassuring to hear. I sometimes think about how AI affects our jobs, identity, and even relationships.
#
# **Liam:** Yeah, AI adds layers we haven’t fully explored yet. Like, how does AI change what it means to connect with each other? When a machine can make your coffee, recommend your next book, or even compose a personalized song for you, where do we draw the line for intimacy?
#
# **Emma:** That’s a profound thought. Reminds me of the class I’m taking on AI in Philosophy. We discuss the moral status of AI and whether they can ever possess consciousness or should be treated as moral agents.
#
# **Liam:** I’d love to sit in on one of those lectures. It aligns with what I often ponder—if AI becomes sophisticated enough to make complex decisions akin to human reasoning, what rights would or should they have?
#
# **Emma:** It’s a Pandora’s box, for sure. But cafes like this, they’re a glimpse into our potential future, showing us both the perks and ethical dilemmas.
#
# **Liam:** Exactly. And while we enjoy our smart lattes and robotically delivered pastries, it’s important to keep questioning and exploring the implications.
#
# **Emma:** *(smiles)* Let’s promise to meet here again in a year and see where AI has taken us. Who knows, maybe by then, the entire conversation could be facilitated by AI!
#
# **Liam:** Now, that would be something. But until then, I’m glad we can enjoy the human touch in our dialogue... even if we’re surrounded by androids.
#
# **[They clink their glasses, the rain outside forming a comforting rhythmic backdrop as the AI hover-bot discreetly collects their empty cups.]**
#
# ---

# %% [markdown]
# # Final Exercise
#
# Refine this prompt to generate an informative and concise summary about the recent advancements in Machine Learning suitable for a general audience. The output should be engaging, simple for the reader and general audiences, with up to 5 sentences of content.
#
# __ASK__
#
#
# __STYLE__
# - Tone:
# - Language:
# - Length:
#
# # Final Exercise Answer
#
# __ASK__
# Provide an informative summary of recent advancements in Machine Learning
#
# __STYLE__
# - Tone: engaging and suitable for general audience
# - Language: engaging simple and upbeat
# - Length: short up to 5 sentences
#
# Machine learning is reaching exciting new heights with some game-changing advancements. Recently, the spotlight has been on generative AI models like OpenAI's ChatGPT and Google's Bard, which can understand and generate human-like text, unlocking creative possibilities across various industries. In healthcare, machine learning is improving diagnostics and personalized medicine, driving more accurate and efficient treatments. Autonomous systems are also making strides, with self-driving technologies becoming safer and more reliable. Lastly, quantum machine learning is on the horizon, promising to tackle complex problems faster than ever before, pushing the boundaries of what's possible in tech and beyond.
